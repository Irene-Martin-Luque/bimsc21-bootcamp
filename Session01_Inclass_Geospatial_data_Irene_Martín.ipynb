# %% [markdown]
# <a href="https://colab.research.google.com/github/Irene-Martin-Luque/bimsc21-bootcamp/blob/main/Session01_Inclass_Geospatial_data_Irene_Mart%C3%ADn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bootcamp structure

# %% [markdown]
# **Learning goals:**
#
# *   Read and write spatial data from/to common file formats
# *   Load geospatial data
# *   Analysis on spatial and non-spatial data
# *   Manage coordinate reference systems and projection
# *   Geocoding data
# *   Geometrical queries
# *   Plotting
# *   Introduction to Python libraries : numpy - pandas- geopandas - matplotlib - shapely - OpenCV
#
# **Sessions:**
#
#
# **Session 01:** How to read and analyze geospatial data using the python [ pandas- geopandas - read and write files ].
#
# **Session 02:** How to query and analyze geometrical data / plotting.
#
# **Session 03:** How to work with image files, read and write batches,  perform image manipulation.

# %% [markdown]
# # Introduction to Colab

# %% [markdown]
# **What is Google Colab?**
#
# If you are quite familiar with Jupyter notebook, then it almost similar to that and you can quickly learn to use Google Colab. To be more precise or in short, you can claim that Google Colab is a free version of the Jupyter notebook environment that entirely build in the cloud. The most important feature of
# Google collab is, it does not require setup and the notebooks that you create can be simultaneously edited by your team members – just the way you edit documents in Google Docs. Colab supports many popular machine learning libraries which can be easily loaded in your notebook.

# %% [markdown]
# *   Write and execute code in Python
# *   Create new notebooks
# *   Upload the existing notebooks
# *   Share the notebooks with the google link
# *   Import data from Google Drive
# *   Import/Publish notebooks from GitHub
# *   Import external datasets e.g. from Kaggle
# *   Integrate PyTorch, TensorFlow, Keras, OpenCV
# *   Free Cloud service with free GPU and TPU

# %% [markdown]
# Colab has two types of cells: text and code. Text cells are formatted using a simple markup language called Markdown.
# To see the Markdown source, double-click a text cell, showing both the Markdown source and the rendered version. Above the Markdown source there is a toolbar to assist editing.
#
# **REFERENCES:**
#
# MARKDOWN
#
# https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=70pYkR9LiOV0
#
# G-DRIVE
#
# https://colab.research.google.com/notebooks/io.ipynb
#
# CHARTS
#
# https://colab.research.google.com/notebooks/charts.ipynb

# %%
#checking installed libraries
#ctrl+f to search for libraries

# %%
#install extra libraries

# %%
#exmaple of installing an extra library


#importing that library

# %% [markdown]
# tools / settings / change colab theme

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#checking python version

# %%
#code cells

#print variables

#print type

# %%
#adding more cells!

# %% [markdown]
# **From tools/settings you can change editor properties such as showing indentation guides and lines numbering**

# %%
#working with loops

# %%
#graphs plotting, having nice visualse on colab

# %% [markdown]
# # Reading files from Gdrive

# %% [markdown]
# Geopandas (http://geopandas.org/) makes it possible to work with geospatial data in Python in a relatively easy way. Geopandas combines the capabilities of the data analysis library pandas with other packages like shapely and fiona for managing spatial data.
#
# The main data structures in geopandas are GeoSeries and GeoDataFrame which extend the capabilities of Series and DataFrames from pandas. This means that we can use all our pandas skills also when working with geopandas! If you need to refresh your memory about pandas, check out week 5 and 6 lesson materials from the Geo-Python website.

# %%
#import Gdrive library

# %%
#mounting Gdrive

# %%
#open a txt file from Gdrive

# %%
#open a json file from Gdrive

# %% [markdown]
# # Reading files using Geopandas

# %%
#install geopandas

# %%
#import geopandas

# %%
#using geopandas to read geojson files

# %%
#checking the type of the file

# %% [markdown]
# # Understanding Dataframes

# %%
#checking the first rows of the data

# %%
#checking the whole dataset

# %%
#checking columns

# %%
#columns filtering, selecting only the geometry column

# %%
#selecting multiple columns

# %% [markdown]
# # Data visualization

# %%
#plotting data as a map
#you can use .plot() -function from geopandas that creates a map based on the geometries of the data based on matplotlib.

# %% [markdown]
# geometries inside the dataframe are stored as shapely objects https://shapely.readthedocs.io/en/stable/manual.html

# %%
# Access one geometry from the data rows

# %% [markdown]
# # Adding Data

# %%
#calculate and print the area of that geomtry

# %%
#geodataframes and geoseries have an attribute area which we can use for accessing the area for each feature at once

# %%
#adding the rounded area column to the dataframe

# %%
#checking the first rows of the new dataframe

# %%
#printing max,min,average of the area column

# %%
#adding centroids as a new column

# %%
#checking the new dataframe

# %%
#Plot overlayed maps(buildings + centroids)

# %% [markdown]
# # Data Conversion

# %%
#checking the whole dataset, we can see here many none data in the osm_id column

# %%
#using dropna() function to clear none items

# %%
#checking the clean dataset

# %%
#keep in mind that a dataframe column is defined as a geo.series similar to pandas series
#the following section should cover how to convert a series to an array
#which might be useful in many applications such as plotting numerical graphs

# %%
#checking the type of the area column

# %%
#converting a series to an array using .to_numpy() function

# %%
#plotting


# setting x and y axis


#setting a range for the y_axis

# %% [markdown]
# # Writing files

# %%
#writing a new json file

# %%
#writing a new csv file

# %% [markdown]
# # Download files

# %%
#zipping files

# %%
#downloading files
